# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\hp\Olist_Project"

# %%
df_customer = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'customers_checked.csv'), index_col=False)

# %%
df_geolocation = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'geolocation_cleaned.csv'), index_col=False)

# %%
df_orders_items = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'order_items_checked.csv'), index_col=False)

# %%
df_order_payments = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'order_payments_checked.csv'), index_col=False)

# %%
df_orders = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_cleaned.csv'), index_col=False)

# %%
df_orders_reviews = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_reviews_checked.csv'), index_col=False)

# %%
df_product_category = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'product_category_cleaned.csv'), index_col=False)

# %%
df_products = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_cleaned.csv'), index_col=False)

# %%
df_sellers = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'sellers_cleaned.csv'), index_col=False)

# %%
df_sellers.head(50)
# Out:
#     Unnamed: 0                         seller_id  seller_zip_code_prefix  \
# 0            0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1            1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2            2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3            3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4            4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
# 5            5  c240c4061717ac1806ae6ee72be3533b                   20920
# 6            6  e49c26c3edfa46d227d5121a6b6e4d37                   55325
# 7            7  1b938a7ec6ac5061a66a3766e0e75f90                   16304
# 8            8  768a86e36ad6aae3d03ee3c6433d61df                    1529
# 9            9  ccc4bbb5f32a6ab2b7066a4130f114e3                   80310
# 10          10  8cb7c5ddf41f4d506eba76e9a4702a25                   75110
# 11          11  a7a9b880c49781da66651ccf4ba9ac38                   13530
# ...

# %%
df_customer.head()
# Out:
#    Unnamed: 0                       customer_id  \
# 0           0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1           1  18955e83d337fd6b2def6b18a428ac77
# 2           2  4e7b3e00288586ebd08712fdd0374a03
# 3           3  b2b6027bc5c5109e529d4dc6358b12c3
# 4           4  4f2d8ab171c80ec8364f7c12e35b23ad
#
#                  customer_unique_id  customer_zip_code_prefix  \
# 0  861eff4711a542e4b93843c6dd7febb0                     14409
# 1  290c77bc529b7ac935b93aa66c333dc3                      9790
# 2  060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3  259dac757896d24d7702b9acbbff3f3c                      8775
# 4  345ecd01c38d18a9036ed96c73b8d066                     13056
#
#            customer_city customer_state
# 0                 franca             SP
# 1  sao bernardo do campo             SP
# 2              sao paulo             SP
# 3        mogi das cruzes             SP
# 4               campinas             SP

# %%
#merge the dataframes
df_merged_cust_orders = df_customer.merge(df_orders, on = 'customer_id', how = "inner")

# %%
df_merged_cust_orders.head()
# Out:
#    Unnamed: 0_x                       customer_id  \
# 0             0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1             1  18955e83d337fd6b2def6b18a428ac77
# 2             2  4e7b3e00288586ebd08712fdd0374a03
# 3             3  b2b6027bc5c5109e529d4dc6358b12c3
# 4             4  4f2d8ab171c80ec8364f7c12e35b23ad
#
#                  customer_unique_id  customer_zip_code_prefix  \
# 0  861eff4711a542e4b93843c6dd7febb0                     14409
# 1  290c77bc529b7ac935b93aa66c333dc3                      9790
# 2  060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3  259dac757896d24d7702b9acbbff3f3c                      8775
# 4  345ecd01c38d18a9036ed96c73b8d066                     13056
#
#            customer_city customer_state  Unnamed: 0_y  \
# 0                 franca             SP         88492
# 1  sao bernardo do campo             SP         90418
# 2              sao paulo             SP         22557
# 3        mogi das cruzes             SP         32180
# ...

# %%
df_merged_cust_orders_items = df_merged_cust_orders.merge(df_orders_items, on=["order_id"], how="inner")

# %%
# Drop duplicate column from df_order_payments
df_order_payments = df_order_payments.drop('Unnamed: 0', axis=1)

# %%
df_merged_cust_orders_items_payments = df_merged_cust_orders_items.merge(df_order_payments, on=["order_id"], how="inner")

# %%
df_merged_cust_orders_items_payments.head()
# Out:
#    Unnamed: 0_x                       customer_id  \
# 0             0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1             1  18955e83d337fd6b2def6b18a428ac77
# 2             2  4e7b3e00288586ebd08712fdd0374a03
# 3             3  b2b6027bc5c5109e529d4dc6358b12c3
# 4             4  4f2d8ab171c80ec8364f7c12e35b23ad
#
#                  customer_unique_id  customer_zip_code_prefix  \
# 0  861eff4711a542e4b93843c6dd7febb0                     14409
# 1  290c77bc529b7ac935b93aa66c333dc3                      9790
# 2  060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3  259dac757896d24d7702b9acbbff3f3c                      8775
# 4  345ecd01c38d18a9036ed96c73b8d066                     13056
#
#            customer_city customer_state  Unnamed: 0_y  \
# 0                 franca             SP         88492
# 1  sao bernardo do campo             SP         90418
# 2              sao paulo             SP         22557
# 3        mogi das cruzes             SP         32180
# ...

# %%
# Drop duplicate column from df_order_payments
df_merged_cust_orders_items_payments = df_merged_cust_orders_items_payments.drop(['Unnamed: 0_x', 'Unnamed: 0_y'], axis=1)

# %%
df_merged_cust_orders_items_payments.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
df_merged_cust_orders_items_payments_reviews = df_merged_cust_orders_items_payments.merge(df_orders_reviews, on=["order_id"], how="inner")

# %%
df_merged_cust_orders_items_payments_reviews.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
df_merged_cust_orders_items_payments_reviews.shape
# Out:
# (114842, 30)

# %%
df_merged_cust_orders_items_payments_reviews.dtypes
# Out:
# customer_id                       object
# customer_unique_id                object
# customer_zip_code_prefix           int64
# customer_city                     object
# customer_state                    object
# order_id                          object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# Unnamed: 0_x                       int64
# order_item_id                      int64
# product_id                        object
# seller_id                         object
# shipping_limit_date               object
# price                            float64
# freight_value                    float64
# payment_sequential                 int64
# payment_type                      object
# payment_installments               int64
# payment_value                    float64
# ...

# %%
df_merged_cust_orders_items_payments_reviews_prod = df_merged_cust_orders_items_payments_reviews.merge(df_products, on=["product_id"], how="inner")

# %%
# Drop duplicate column from df_order_payments
df_merged_cust_orders_items_payments_reviews_prod = df_merged_cust_orders_items_payments_reviews_prod.drop(['Unnamed: 0_x', 'Unnamed: 0_y'], axis=1)

# %%
df_merged_cust_orders_items_payments_reviews_prod_seller = df_merged_cust_orders_items_payments_reviews_prod.merge(df_sellers, 
                                                                                                                   on=["seller_id"], how="inner")

# %%
df_merged_cust_orders_items_payments_reviews_prod_seller.dtypes
# Out:
# customer_id                       object
# customer_unique_id                object
# customer_zip_code_prefix           int64
# customer_city                     object
# customer_state                    object
# order_id                          object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# order_item_id                      int64
# product_id                        object
# seller_id                         object
# shipping_limit_date               object
# price                            float64
# freight_value                    float64
# payment_sequential                 int64
# payment_type                      object
# payment_installments               int64
# payment_value                    float64
# review_id                         object
# ...

# %%
df_sellers.head()
# Out:
#    Unnamed: 0                         seller_id  seller_zip_code_prefix  \
# 0           0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1           1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2           2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3           3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4           4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
df_geolocation.head()
# Out:
#    Unnamed: 0  geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0           0                         1037       -23.545621       -46.639292
# 1           1                         1046       -23.546081       -46.644820
# 2           2                         1046       -23.546129       -46.642951
# 3           3                         1041       -23.544392       -46.639499
# 4           4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
df_geolocation.rename(columns={'geolocation_zip_code_prefix': 'customer_zip_code_prefix'}, inplace=True)

# %%
df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc = df_merged_cust_orders_items_payments_reviews_prod_seller.merge(df_geolocation,on = ["customer_zip_code_prefix"], how = "inner")

# %%
df_product_category.head()
# Out:
#    Unnamed: 0   product_category_name product_category_name_english
# 0           0            beleza_saude                 health_beauty
# 1           1  informatica_acessorios         computers_accessories
# 2           2              automotivo                          auto
# 3           3         cama_mesa_banho                bed_bath_table
# 4           4        moveis_decoracao               furniture_decor

# %%
df_products.head()
# Out:
#    Unnamed: 0                        product_id  product_category_name  \
# 0           0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1           1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2           2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3           3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4           4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_length  product_description_length  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_grms  product_length_cm  product_height_cm  product_width_cm
# ...

# %%
# Drop duplicate column
df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc = df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc.drop(['Unnamed: 0_x', 'Unnamed: 0_y'], axis=1)

# %%
df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc_prodcat = df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc.merge(df_product_category,on = ["product_category_name"], how = "inner")

# %%
df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc_prodcat.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                     14409        franca             SP
# 1                     14409        franca             SP
# 2                     14409        franca             SP
# 3                     14409        franca             SP
# 4                     14409        franca             SP
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# ...

# %%
# Drop duplicate column
df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc_prodcat = df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc_prodcat.drop(['Unnamed: 0_x', 'Unnamed: 0_y'], axis=1)

# %%
df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc_prodcat.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                     14409        franca             SP
# 1                     14409        franca             SP
# 2                     14409        franca             SP
# 3                     14409        franca             SP
# 4                     14409        franca             SP
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# ...

# %%
df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc_prodcat.dtypes
# Out:
# customer_id                       object
# customer_unique_id                object
# customer_zip_code_prefix           int64
# customer_city                     object
# customer_state                    object
# order_id                          object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# order_item_id                      int64
# product_id                        object
# seller_id                         object
# shipping_limit_date               object
# price                            float64
# freight_value                    float64
# payment_sequential                 int64
# payment_type                      object
# payment_installments               int64
# payment_value                    float64
# review_id                         object
# ...

# %%
# Drop duplicate column 
df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc_prodcat = df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc_prodcat.drop(['product_category_name', 'review_id', 'review_comment_title', 'review_comment_message'], axis=1)

# %%
df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc_prodcat.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                     14409        franca             SP
# 1                     14409        franca             SP
# 2                     14409        franca             SP
# 3                     14409        franca             SP
# 4                     14409        franca             SP
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# ...

# %%
df_merged_all = df_merged_cust_orders_items_payments_reviews_prod_seller_geoloc_prodcat

# %%
df_merged_all.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                     14409        franca             SP
# 1                     14409        franca             SP
# 2                     14409        franca             SP
# 3                     14409        franca             SP
# 4                     14409        franca             SP
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# ...

# %%
df_merged_all.dtypes
# Out:
# customer_id                       object
# customer_unique_id                object
# customer_zip_code_prefix           int64
# customer_city                     object
# customer_state                    object
# order_id                          object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# order_item_id                      int64
# product_id                        object
# seller_id                         object
# shipping_limit_date               object
# price                            float64
# freight_value                    float64
# payment_sequential                 int64
# payment_type                      object
# payment_installments               int64
# payment_value                    float64
# review_score                       int64
# ...

# %%
df_merged_all.describe()
# Out:
#        customer_zip_code_prefix  order_item_id         price  freight_value  \
# count              1.184547e+07   1.184547e+07  1.184547e+07   1.184547e+07
# mean               3.432673e+04   1.203269e+00  1.201242e+02   1.972851e+01
# std                2.747453e+04   6.972083e-01  1.814716e+02   1.493804e+01
# min                1.003000e+03   1.000000e+00  8.500000e-01   0.000000e+00
# 25%                1.329500e+04   1.000000e+00  3.999000e+01   1.351000e+01
# 50%                2.612000e+04   1.000000e+00  7.490000e+01   1.633000e+01
# 75%                3.875000e+04   1.000000e+00  1.349000e+02   2.069000e+01
# max                9.998000e+04   2.100000e+01  6.735000e+03   4.096800e+02
#
#        payment_sequential  payment_installments  payment_value  review_score  \
# count        1.184547e+07          1.184547e+07   1.184547e+07  1.184547e+07
# mean         1.090650e+00          2.973990e+00   1.725282e+02  4.081770e+00
# ...

# %%
df_merged_all.shape
# Out:
# (11845472, 40)

# %%
df_merged_all[df_merged_all.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state, order_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value, payment_sequential, payment_type, payment_installments, payment_value, review_score, review_creation_date, review_answer_timestamp, product_name_length, product_description_length, product_photos_qty, product_weight_grms, product_length_cm, product_height_cm, product_width_cm, seller_zip_code_prefix, seller_city, seller_state, geolocation_lat, geolocation_lng, geolocation_city, geolocation_state, product_category_name_english]
# Index: []
#
# [0 rows x 40 columns]

# %%
df_merged_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11845472 entries, 0 to 11845471
# Data columns (total 40 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   customer_id                    object
#  1   customer_unique_id             object
#  2   customer_zip_code_prefix       int64
#  3   customer_city                  object
#  4   customer_state                 object
#  5   order_id                       object
#  6   order_status                   object
#  7   order_purchase_timestamp       object
#  8   order_approved_at              object
#  9   order_delivered_carrier_date   object
#  10  order_delivered_customer_date  object
#  11  order_estimated_delivery_date  object
#  12  order_item_id                  int64
#  13  product_id                     object
#  14  seller_id                      object
#  15  shipping_limit_date            object
#  16  price                          float64
# ...

# %%
for col in df_merged_all.columns.tolist():
    weird = (df_merged_all [[col]].map(type) != df_merged_all[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_merged_all[weird]) > 0:
        print(col)

# %%
df_merged_all.isnull().sum()
# Out:
# customer_id                      0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# order_id                         0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# review_score                     0
# review_creation_date             0
# review_answer_timestamp          0
# product_name_length              0
# product_description_length       0
# ...

# %%
#changing the data type to reduce the size of the file
df_merged_all = df_merged_all.astype({
    'customer_zip_code_prefix': 'float32',
    'order_item_id': 'int32',
    'freight_value': 'float32',
    'payment_sequential': 'int32',
    'payment_installments': 'int32',
    'review_score': 'int16',
    'product_name_length': 'float16',
    'product_description_length': 'float16',
    'product_photos_qty': 'int16',
    'product_weight_grms': 'float32',
    'product_length_cm': 'float32',
    'product_height_cm': 'float32',
    'product_width_cm': 'float32',
    'seller_zip_code_prefix': 'int16',
    'geolocation_lat': 'float32',
    'geolocation_lng': 'float32'
        })

# %%
df_merged_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11845472 entries, 0 to 11845471
# Data columns (total 40 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   customer_id                    object
#  1   customer_unique_id             object
#  2   customer_zip_code_prefix       float32
#  3   customer_city                  object
#  4   customer_state                 object
#  5   order_id                       object
#  6   order_status                   object
#  7   order_purchase_timestamp       object
#  8   order_approved_at              object
#  9   order_delivered_carrier_date   object
#  10  order_delivered_customer_date  object
#  11  order_estimated_delivery_date  object
#  12  order_item_id                  int32
#  13  product_id                     object
#  14  seller_id                      object
#  15  shipping_limit_date            object
#  16  price                          float64
# ...

# %%
# Exporting the cleaned and merged data
df_merged_all.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'merged_all.csv'))

# %%
df_merged_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11845472 entries, 0 to 11845471
# Data columns (total 40 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   customer_id                    object
#  1   customer_unique_id             object
#  2   customer_zip_code_prefix       float32
#  3   customer_city                  object
#  4   customer_state                 object
#  5   order_id                       object
#  6   order_status                   object
#  7   order_purchase_timestamp       object
#  8   order_approved_at              object
#  9   order_delivered_carrier_date   object
#  10  order_delivered_customer_date  object
#  11  order_estimated_delivery_date  object
#  12  order_item_id                  int32
#  13  product_id                     object
#  14  seller_id                      object
#  15  shipping_limit_date            object
#  16  price                          float64
# ...
